# %%
# %matplotlib qt
exec(open("simpleq-2nd-RK4.py").read())
# Out:
# x[N] is 3.0000000000004805
# y[N] is -1.7315585611986395
# err is 8.579959587251551e-08
# log10 of err is -7.066514757731129
# It took 0.28 seconds for this script to run.

# %%
x
# Out:
# array([[0.0000e+00],
#        [3.0000e-04],
#        [6.0000e-04],
#        ...,
#        [2.9994e+00],
#        [2.9997e+00],
#        [3.0000e+00]])

# %%
plt.plot(y,dy)
